# %%
import math
import scipy
import math
import numpy as np
import matplotlib.pyplot as plt
def T(t):
    r=25
    tau=math.log(r/0.167 -1)
    a=r/(1+math.e**(-t+tau))
    return a
T(4)    

def pv(t):
    a=8.341*T(t)
    print(a)

# %%
x=np.linspace(0,50,500)
y=T(x)
plt.plot(x,y)
plt.show()

# %%
T(4)*8.341
# Out:
# 152.52328183462419
